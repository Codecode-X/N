# %%
import torch
import clip
from PIL import Image

device = "cpu" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/16", device=device)

# %%
image_path = "exp/input_images/下半身（上红下白）.png"
choices = ["Red on the bottom", "Red on the up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["bottom", "up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["white on the bottom", "white on the up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 

### clip主要还是关注这个图片是某个人的下半身，而没有关注颜色
# Out:
# ['Red on the bottom', 'Red on the up']
# Label probs: [[0.58537245 0.41462752]]
# ['bottom', 'up']
# Label probs: [[0.83317596 0.16682409]]
# ['white on the bottom', 'white on the up']
# Label probs: [[0.69378424 0.30621573]]

# %%
image_path = "exp/input_images/下半身（上红下白）.png"
choices = ["Red on the bottom", "Red on the up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["bottom", "up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["white on the bottom", "white on the up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 

### clip主要还是关注这个图片是某个人的下半身，而没有关注实际的prompt
# Out:
# ['Red on the bottom', 'Red on the up']
# Label probs: [[0.58537245 0.41462752]]
# ['bottom', 'up']
# Label probs: [[0.83317596 0.16682409]]
# ['white on the bottom', 'white on the up']
# Label probs: [[0.69378424 0.30621573]]

# %%
image_path = "exp/input_images/上半身（上红下白）.png"
choices = ["Red on the bottom", "Red on the up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["bottom", "up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["white on the bottom", "white on the up"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 

### clip主要还是关注这个图片是某个人的上半身，而没有关注实际的prompt，可能是prompt写的不好
# Out:
# ['Red on the bottom', 'Red on the up']
# Label probs: [[0.3040683 0.6959317]]
# ['bottom', 'up']
# Label probs: [[0.0891357  0.91086423]]
# ['white on the bottom', 'white on the up']
# Label probs: [[0.5481813  0.45181873]]

# %%
image_path = "exp/input_images/上半身（上红下白）.png"
choices = ["T-shirt", "pant"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


image_path = "exp/input_images/下半身（上红下白）.png"
choices = ["T-shirt", "pant"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs)
# Out:
# ['T-shirt', 'pant']
# Label probs: [[0.68590677 0.3140933 ]]
# ['T-shirt', 'pant']
# Label probs: [[0.02788545 0.97211456]]

# %%
image_path = "exp/input_images/raw.png"
choices = ["Red T-shirt on the left", "White T-shirt in the left", "Blue T-shirt on the left"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["Red T-shirt on the middle", "White T-shirt in the middle", "Blue T-shirt on the middle"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 


choices = ["Red T-shirt on the right", "White T-shirt in the right", "Blue T-shirt on the right"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 

choices = ["red", "white", "blue"]
image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
text = clip.tokenize(choices).to(device)

with torch.no_grad():
    image_features = model.encode_image(image)
    text_features = model.encode_text(text)
    
    logits_per_image, logits_per_text = model(image, text)
    probs = logits_per_image.softmax(dim=-1).cpu().numpy()

print(choices)
print("Label probs:", probs) 

"""
这说明 CLIP 对「颜色」的识别能力较强，但对「相对位置（左/中/右）」的理解很差。

原因可能包括：
* CLIP 不是专门为「位置理解」训练的
* CLIP 主要用于 图像-文本匹配，但它的训练数据集中「位置描述」较少。它更擅长匹配 物体类别（如「红衣人」），但对于「左边/右边」等相对位置信息的理解可能很弱。
"""
# Out:
# ['Red T-shirt on the left', 'White T-shirt in the left', 'Blue T-shirt on the left']
# Label probs: [[    0.18463      0.1542     0.66117]]
# ['Red T-shirt on the middle', 'White T-shirt in the middle', 'Blue T-shirt on the middle']
# Label probs: [[    0.16394     0.16408     0.67198]]
# ['Red T-shirt on the right', 'White T-shirt in the right', 'Blue T-shirt on the right']
# Label probs: [[    0.20035     0.10755     0.69211]]
# ['red', 'white', 'blue']
# Label probs: [[   0.057408     0.56926     0.37333]]
# '\n这说明 CLIP 对「颜色」的识别能力较强，但对「相对位置（左/中/右）」的理解很差。\n\n原因可能包括：\n* CLIP 不是专门为「位置理解」训练的\n* CLIP 主要用于 图像-文本匹配，但它的训练数据集中「位置描述」较少。它更擅长匹配 物体类别（如「红衣人」），但对于「左边/右边」等相对位置信息的理解可能很弱。\n'

# %% [markdown]
# ### 其他

# %% [markdown]
# #### 可视化注意力权重

# %%
from tools.visualization import display_attn_weight, display_img_attn

display_attn_weight("exp/input_images/raw.png")

# %%
from tools.visualization import display_attn_weight, display_img_attn

display_img_attn("exp/input_images/raw.png")
# Out:
# (12, 1, 49)

# %%
from tools.visualization import display_attn_weight, display_img_attn

display_img_attn("exp/input_images/dogcat.png")
# Out:
# (12, 1, 49)

# %% [markdown]
# ### 其他

# %% [markdown]
# #### 目标检测+clip

# %%
"""目标检测+clip"""

from ultralytics import YOLO
import clip
import torch
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# 加载 YOLO 目标检测模型
yolo_model = YOLO("yolov8n.pt")  # 轻量级模型
image_path = "exp/input_images/raw.png"

# 目标检测
image = Image.open(image_path)
results = yolo_model(image) # 返回batchsize个result

# 遍历检测到的目标
fig, axs = plt.subplots(1, len(results[0].boxes), figsize=(15, 5))  # 创建子图

for idx, box in enumerate(results[0].boxes):
    x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())  # 获取 bbox 坐标
    cropped = image.crop((x1, y1, x2, y2))  # 裁剪人物

    # 计算位置（左、中、右）
    width = image.width
    if x1 < width / 3:
        position = "left"
    elif x2 > 2 * width / 3:
        position = "right"
    else:
        position = "middle"

    # CLIP 识别颜色
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model, preprocess = clip.load("ViT-B/32", device=device)
    
    image_tensor = preprocess(cropped).unsqueeze(0).to(device)
    text = clip.tokenize(["red", "white", "blue"]).to(device)

    with torch.no_grad():
        logits_per_image, _ = model(image_tensor, text)
        probs = logits_per_image.softmax(dim=-1).cpu().numpy()

    color = ["red", "white", "blue"][probs.argmax()]
    
    # 显示裁剪后的人物
    axs[idx].imshow(cropped)
    axs[idx].set_title(f"{position}: {results[0].names[int(box.cls)]}-{color}", fontsize=12)
    axs[idx].axis("off")

plt.tight_layout()
plt.show()
# Out:
# 0: 544x640 3 persons, 2 remotes, 238.4ms
# Speed: 15.1ms preprocess, 238.4ms inference, 1.4ms postprocess per image at shape (1, 3, 544, 640)
